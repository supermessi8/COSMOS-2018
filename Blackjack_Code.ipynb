# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/supermessi8/COSMOS-2018/blob/master/Blackjack_Code.ipynb)

# %%
#BLACKJACK GAME FULL WITH DECK THAT SHUFFLES EVERYTIME
import numpy as N
import matplotlib.pyplot as plt
import random


#n is the number which the player holds at
def game(n, loops):
  tie = 0 #Tie
  playerWin = 0 #Player wins
  houseWin = 0 #House wins
  playerValueArray = []
  houseValueArray= []
  

  for i in range(loops):
    #creates deck
    deck = {'Ace of Hearts':11, '2 of Hearts':2, '3 of Hearts':3,'4 of Hearts':4, '5 of Hearts':5, '6 of Hearts':6, '7 of Hearts':7, 
            '8 of Hearts':8, '9 of Hearts':9, '10 of Hearts':10,'Jack of Hearts':10, 'Queen of Hearts':10, 'King of Hearts':10, 'Ace of Diamonds':11, 
            '2 of Diamonds':2, '3 of Diamonds':3,'4 of Diamonds':4,'5 of Diamonds':5, '6 of Diamonds':6, '7 of Diamonds':7, '8 of Diamonds':8, '9 of Diamonds':9, '10 of Diamonds':10, 
            'Jack of Diamonds':10, 'Queen of Diamonds':10, 'King of Diamonds':10,'Ace of Spades':11, '2 of Spades':2, '3 of Spades':3,'4 of Spades':4, '5 of Spades':5, '6 of Spades':6, '7 of Spades':7, '8 of Spades':8, '9 of Spades':9, '10 of Spades':10, 
            'Jack of Spades':10, 'Queen of Spades':10, 'King of Spades':10,'Ace of Clubs':11, '2 of Clubs':2, '3 of Clubs':3,'4 of Clubs':4, 
            '5 of Clubs':5, '6 of Clubs':6, '7 of Clubs':7, '8 of Clubs':8, '9 of Clubs':9, '10 of Clubs':10, 'Jack of Clubs':10, 'Queen of Clubs':10, 'King of Clubs':10}
  
    #list to call cards (LISTS ARE DIFFERENT FROM ARRAYS)
    deckindex = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
                '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
              '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
              'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
              'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
              '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
    countPlayerAce = 0
    countHouseAce = 0
    houseValue = 0 #House sum
    playerValue = 0 #Player sum
   
    #gives house and player both initial two cards
    card = deckindex.pop(random.randint(0,len(deckindex)-1))
    playerValue += deck[card]
    if deck[card] == 11:
      countPlayerAce += 1
    houseCard = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
    houseValue += houseCard
    if houseCard == 11:
      countHouseAce += 1
    card = deckindex.pop(random.randint(0,len(deckindex)-1))
    playerValue += deck[card]
    if deck[card] == 11:
      countPlayerAce += 1
    houseCard = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
    houseValue += houseCard
    if houseCard == 11:
      countHouseAce += 1
    #You win if you have 21 from two initial cards
    if playerValue == 21:
      playerWin += 1
    else:
      #both player and house take their turns hitting
      while (playerValue < n):
        add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
        if add == 11:
          countPlayerAce += 1
        playerValue += add
        if playerValue > 21 and countPlayerAce > 0:
          playerValue -= 10
          countPlayerAce -= 1
      if houseValue == 21:
        houseWin += 1
      else:
        while (houseValue < 17):
          add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
          if add == 11:
            countHouseAce += 1
          houseValue += add
          if houseValue > 21 and countHouseAce > 0:
            houseValue -= 10
            countHouseAce -= 1
        #checks whether there are ties or who wins
        if playerValue > 21:
          houseWin += 1
        elif houseValue > 21:
          playerWin +=1
        elif playerValue == houseValue:
          tie += 1
        else:
          if playerValue > houseValue:
            playerWin += 1
          else:
            houseWin += 1
    playerValueArray.append(playerValue)
    houseValueArray.append(houseValue)
  print(playerWin + houseWin + tie)
  print(str(n) + " Player Wins: " + str(1.0 * playerWin / loops))
  return 1.0 * playerWin / loops, playerValueArray, houseValueArray

wins,playerArray,houseArray=game(14,100)
print(playerArray)
print(houseArray)
plt.title("Player Win Percentage by Standing at 14")
plt.xlabel("Number of Games")
plt.ylabel("Total Sum of the Cards")
plt.plot(playerArray,label="player")
plt.plot(houseArray,label="house")
plt.legend()
plt.plot([21]*100)
# Out:
# 100
# 14 Player Wins: 0.42
# [21, 16, 17, 17, 19, 18, 18, 16, 20, 16, 19, 21, 17, 18, 20, 17, 19, 16, 22, 17, 15, 20, 20, 19, 14, 18, 22, 18, 16, 17, 15, 14, 15, 14, 22, 16, 19, 20, 21, 19, 18, 20, 16, 20, 14, 14, 14, 23, 18, 14, 20, 19, 23, 16, 15, 20, 16, 18, 14, 15, 17, 17, 21, 20, 14, 20, 15, 14, 15, 20, 14, 15, 15, 14, 19, 17, 19, 20, 14, 17, 16, 20, 19, 16, 15, 18, 20, 17, 19, 18, 14, 16, 17, 23, 14, 19, 16, 14, 14, 21]
# [19, 17, 18, 22, 19, 17, 19, 22, 18, 21, 26, 18, 23, 26, 23, 19, 26, 17, 17, 20, 19, 20, 17, 19, 23, 17, 18, 22, 23, 23, 19, 26, 20, 21, 17, 18, 24, 22, 23, 20, 17, 18, 19, 18, 20, 19, 21, 20, 26, 24, 21, 19, 19, 21, 18, 22, 20, 17, 20, 17, 20, 22, 16, 20, 20, 24, 17, 18, 21, 19, 22, 17, 20, 22, 20, 24, 22, 20, 22, 19, 19, 22, 21, 17, 23, 21, 19, 19, 21, 19, 21, 17, 25, 19, 19, 19, 18, 21, 18, 19]

# %%
#BLACKJACK FULL GAME THAT HAS DECK SHUFFLE WHEN CARDS RUN OUT
import numpy as N
import matplotlib.pyplot as plt
import random

#creates new deck
def makeDeck():
  d = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
         '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
         '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
         'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
         'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
         '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
  return d

#n is the number which the player holds at
def game(n, loops):
  tie = 0 #Tie
  playerWin = 0 #Player wins
  houseWin = 0 #House wins
  playerValueArray = []
  houseValueArray= []
  
  #creates deck
  deck = {'Ace of Hearts':11, '2 of Hearts':2, '3 of Hearts':3,'4 of Hearts':4, '5 of Hearts':5, '6 of Hearts':6, '7 of Hearts':7, 
         '8 of Hearts':8, '9 of Hearts':9, '10 of Hearts':10,'Jack of Hearts':10, 'Queen of Hearts':10, 'King of Hearts':10, 'Ace of Diamonds':11, 
         '2 of Diamonds':2, '3 of Diamonds':3,'4 of Diamonds':4,'5 of Diamonds':5, '6 of Diamonds':6, '7 of Diamonds':7, '8 of Diamonds':8, '9 of Diamonds':9, '10 of Diamonds':10, 
         'Jack of Diamonds':10, 'Queen of Diamonds':10, 'King of Diamonds':10,'Ace of Spades':11, '2 of Spades':2, '3 of Spades':3,'4 of Spades':4, '5 of Spades':5, '6 of Spades':6, '7 of Spades':7, '8 of Spades':8, '9 of Spades':9, '10 of Spades':10, 
         'Jack of Spades':10, 'Queen of Spades':10, 'King of Spades':10,'Ace of Clubs':11, '2 of Clubs':2, '3 of Clubs':3,'4 of Clubs':4, 
         '5 of Clubs':5, '6 of Clubs':6, '7 of Clubs':7, '8 of Clubs':8, '9 of Clubs':9, '10 of Clubs':10, 'Jack of Clubs':10, 'Queen of Clubs':10, 'King of Clubs':10}
  
  #list to call cards (LISTS ARE DIFFERENT FROM ARRAYS)
  deckindex = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
              '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
              '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
              'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
              'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
              '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
    #deckindex = deckindex * x
  for i in range(loops):
    countPlayerAce = 0
    countHouseAce = 0
    houseValue = 0 #House sum
    playerValue = 0 #Player sum

    #gives house and player their both initial two cards
    if len(deckindex) == 0:
      deckindex = makeDeck()
    card = deckindex.pop(random.randint(0,len(deckindex)-1))
    playerValue += deck[card]
    if deck[card] == 11:
      countPlayerAce += 1
    if len(deckindex) == 0:
      deckindex = makeDeck()
    houseCard = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
    houseValue += houseCard
    if houseCard == 11:
      countHouseAce += 1
    if len(deckindex) == 0:
      deckindex = makeDeck()
    card = deckindex.pop(random.randint(0,len(deckindex)-1))
    playerValue += deck[card]
    if deck[card] == 11:
      countPlayerAce += 1
    if len(deckindex) == 0:
      deckindex = makeDeck()
    houseCard = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
    houseValue += houseCard
    if houseCard == 11:
      countHouseAce += 1
      
    #if you get 21 you win
    if playerValue == 21:
      playerWin += 1
    else:
      #both player and house take their turns hitting
      while (playerValue < n):
        if len(deckindex) == 0:
          deckindex = makeDeck()
        add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
        if add == 11:
          countPlayerAce += 1
        playerValue += add
        if playerValue > 21 and countPlayerAce > 0:
          playerValue -= 10
          countPlayerAce -= 1
      if houseValue == 21:
        houseWin += 1
      else:
        while (houseValue < 17):
          if len(deckindex) == 0:
            deckindex = makeDeck()
          add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
          if add == 11:
            countHouseAce += 1
          houseValue += add
          if houseValue > 21 and countHouseAce > 0:
            houseValue -= 10
            countHouseAce -= 1
        #checks whether there are ties or who wins
        if playerValue > 21:
          houseWin += 1
        elif houseValue > 21:
          playerWin +=1
        elif playerValue == houseValue:
          tie += 1
        else:
          if playerValue > houseValue:
            playerWin += 1
          else:
            houseWin += 1
    playerValueArray.append(playerValue)
    houseValueArray.append(houseValue)
  print(str(n) + " Player Wins: " + str(1.0 * playerWin / loops))
  return 1.0 * playerWin / loops

#plot
wins = [game(i+1, 100000) for i in range(21)]
xAxis = [i+1 for i in range(21)]
plt.figure()
plt.xticks(N.arange(1,22,1))
plt.title("Player Win Percentage based on Strategy")
plt.xlabel("Number Player Stands At")
plt.ylabel("Percentage of Wins")
plt.plot(xAxis,wins)
plt.show()
# Out:
# 1 Player Wins: 0.39404
# 2 Player Wins: 0.39095
# 3 Player Wins: 0.39202
# 4 Player Wins: 0.39091
# 5 Player Wins: 0.38958
# 6 Player Wins: 0.39059
# 7 Player Wins: 0.39077
# 8 Player Wins: 0.39001
# 9 Player Wins: 0.39221
# 10 Player Wins: 0.3984
# 11 Player Wins: 0.40643
# 12 Player Wins: 0.42216
# 13 Player Wins: 0.42508
# 14 Player Wins: 0.42627
# 15 Player Wins: 0.42302
# 16 Player Wins: 0.41923
# 17 Player Wins: 0.41392
# 18 Player Wins: 0.40208
# 19 Player Wins: 0.36524
# 20 Player Wins: 0.2975
# 21 Player Wins: 0.16534

# %%
#BLACKJACK FULL GAME THAT HAS DECK SHUFFLE WHEN CARDS RUN OUT WITH TWO PLAYERS
import numpy as N
import matplotlib.pyplot as plt
import random

#creates new deck
def makeDeck():
  d = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
         '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
         '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
         'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
         'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
         '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
  return d

#n is the number which the player holds at
def game(n, n2, loops):
  tie = 0 #Tie
  playerWin = 0 #Player wins
  playerWin2 = 0 #Player 2 wins
  houseWin = 0 #House wins
  playerValueArray = []
  houseValueArray= []
  playerValue2Array=[]
  #creates deck
  deck = {'Ace of Hearts':11, '2 of Hearts':2, '3 of Hearts':3,'4 of Hearts':4, '5 of Hearts':5, '6 of Hearts':6, '7 of Hearts':7, 
         '8 of Hearts':8, '9 of Hearts':9, '10 of Hearts':10,'Jack of Hearts':10, 'Queen of Hearts':10, 'King of Hearts':10, 'Ace of Diamonds':11, 
         '2 of Diamonds':2, '3 of Diamonds':3,'4 of Diamonds':4,'5 of Diamonds':5, '6 of Diamonds':6, '7 of Diamonds':7, '8 of Diamonds':8, '9 of Diamonds':9, '10 of Diamonds':10, 
         'Jack of Diamonds':10, 'Queen of Diamonds':10, 'King of Diamonds':10,'Ace of Spades':11, '2 of Spades':2, '3 of Spades':3,'4 of Spades':4, '5 of Spades':5, '6 of Spades':6, '7 of Spades':7, '8 of Spades':8, '9 of Spades':9, '10 of Spades':10, 
         'Jack of Spades':10, 'Queen of Spades':10, 'King of Spades':10,'Ace of Clubs':11, '2 of Clubs':2, '3 of Clubs':3,'4 of Clubs':4, 
         '5 of Clubs':5, '6 of Clubs':6, '7 of Clubs':7, '8 of Clubs':8, '9 of Clubs':9, '10 of Clubs':10, 'Jack of Clubs':10, 'Queen of Clubs':10, 'King of Clubs':10}
  
  #list to call cards (LISTS ARE DIFFERENT FROM ARRAYS)
  deckindex = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
              '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
              '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
              'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
              'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
              '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']

  for i in range(loops):
    countPlayerAce = 0
    countPlayer2Ace = 0
    countHouseAce = 0
    houseValue = 0 #House sum
    playerValue = 0 #Player sum
    playerValue2 = 0 #Player 2 sum
    
    #gives house and player their both initial two cards
    if len(deckindex) == 0:
      deckindex = makeDeck()
    card = deckindex.pop(random.randint(0,len(deckindex)-1))
    playerValue += deck[card]
    if deck[card] == 11:
      countPlayerAce += 1
    if len(deckindex) == 0:
      deckindex = makeDeck()
    card = deckindex.pop(random.randint(0,len(deckindex)-1))
    playerValue2 += deck[card]
    if deck[card] == 11:
      countPlayer2Ace += 1
    if len(deckindex) == 0:
      deckindex = makeDeck()
    houseCard = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
    houseValue += houseCard
    if houseCard == 11:
      countHouseAce += 1
    if len(deckindex) == 0:
      deckindex = makeDeck()
    card = deckindex.pop(random.randint(0,len(deckindex)-1))
    playerValue += deck[card]
    if deck[card] == 11:
      countPlayerAce += 1
    if len(deckindex) == 0:
      deckindex = makeDeck()
    card = deckindex.pop(random.randint(0,len(deckindex)-1))
    playerValue2 += deck[card]
    if deck[card] == 11:
      countPlayer2Ace += 1
    if len(deckindex) == 0:
      deckindex = makeDeck()
    houseCard = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
    houseValue += houseCard
    if houseCard == 11:
      countHouseAce += 1

    #if you get 21 you win
    if playerValue == 21:
      playerWin += 1
    else:
      #both player and house take their turns hitting
      while (playerValue < n):
        if len(deckindex) == 0:
          deckindex = makeDeck()
        add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
        if add == 11:
          countPlayerAce += 1
        playerValue += add
        if playerValue > 21 and countPlayerAce > 0:
          playerValue -= 10
          countPlayerAce -= 1
      if playerValue2 == 21:
        playerWin2 += 1
      while (playerValue2 < n2):
        if len(deckindex) == 0:
          deckindex = makeDeck()
        add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
        if add == 11:
          countPlayer2Ace += 1
        playerValue2 += add
        if playerValue2 > 21 and countPlayer2Ace > 0:
          playerValue2 -= 10
          countPlayer2Ace -= 1
      
      if houseValue == 21:
        houseWin += 1
      else:
        while (houseValue < 17):
          if len(deckindex) == 0:
            deckindex = makeDeck()
          add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
          if add == 11:
            countHouseAce += 1
          houseValue += add
          if houseValue > 21 and countHouseAce > 0:
            houseValue -= 10
            countHouseAce -= 1
        #checks whether there are ties or who wins
        if playerValue > 21:
          houseWin += 1
        elif houseValue > 21:
          playerWin +=1
        elif playerValue == houseValue:
          tie += 1
        elif (playerValue == houseValue):
          tie += 1
        else:
          if (playerValue > houseValue):
            playerWin += 1
            
        if playerValue2 > 21:
          houseWin += 1
        elif houseValue > 21:
          playerWin2 +=1
        elif playerValue2 == houseValue:
          tie += 1
        else:
          if playerValue2 > houseValue:
            playerWin2 += 1
          else:
            houseWin += 1
    playerValueArray.append(playerValue)
    playerValue2Array.append(playerValue2)
    houseValueArray.append(houseValue)
  print(str(n) + " Player Wins: " + str(1.0 * playerWin / loops) + " Player2 Wins: " + str(1.0*playerWin2 / loops) + " Dealer: " + str(1.0*houseWin/loops))
  #return 1.0 * playerWin / loops, playerValueArray, playerValue2Array, houseValueArray
  return 1.0*playerWin/loops, 1.0*playerWin2/loops, 1.0*houseWin/loops

plt.figure()
playerWin = []
playerWin2 = []
houseWin = []
for i in range(21):
  pWin,p2Win,hWin=game(i+1,i+1, 100000)
  playerWin.append(pWin)
  playerWin2.append(p2Win)
  houseWin.append(hWin)

xAxis = [i+1 for i in range(21)]
plt.figure()
plt.xticks(N.arange(1,22,1))
plt.title("Player Win Percentage based on Strategy")
plt.xlabel("Number Player Stands At")
plt.ylabel("Percentage of Wins")
plt.plot(xAxis,playerWin,label="player1")
plt.plot(xAxis,playerWin2,label="player2")
plt.plot(xAxis,houseWin,label="dealer")
plt.legend()
plt.show()
# Out:
# 1 Player Wins: 0.38807 Player2 Wins: 0.41176 Dealer: 0.54504
# 2 Player Wins: 0.38767 Player2 Wins: 0.41198 Dealer: 0.54669
# 3 Player Wins: 0.38989 Player2 Wins: 0.41186 Dealer: 0.54528
# 4 Player Wins: 0.38984 Player2 Wins: 0.41316 Dealer: 0.54481
# 5 Player Wins: 0.39057 Player2 Wins: 0.41217 Dealer: 0.54555
# 6 Player Wins: 0.38808 Player2 Wins: 0.41208 Dealer: 0.54595
# 7 Player Wins: 0.38932 Player2 Wins: 0.41139 Dealer: 0.54489
# 8 Player Wins: 0.38884 Player2 Wins: 0.41227 Dealer: 0.54533
# 9 Player Wins: 0.39263 Player2 Wins: 0.41538 Dealer: 0.53906
# 10 Player Wins: 0.39558 Player2 Wins: 0.41716 Dealer: 0.53231
# 11 Player Wins: 0.4096 Player2 Wins: 0.43145 Dealer: 0.5168
# 12 Player Wins: 0.42096 Player2 Wins: 0.44464 Dealer: 0.4979
# 13 Player Wins: 0.4232 Player2 Wins: 0.44445 Dealer: 0.52629
# 14 Player Wins: 0.42554 Player2 Wins: 0.44849 Dealer: 0.56015
# 15 Player Wins: 0.42663 Player2 Wins: 0.44764 Dealer: 0.60239
# 16 Player Wins: 0.42005 Player2 Wins: 0.44378 Dealer: 0.66861
# 17 Player Wins: 0.41402 Player2 Wins: 0.43317 Dealer: 0.74665
# 18 Player Wins: 0.40346 Player2 Wins: 0.42638 Dealer: 0.85955
# 19 Player Wins: 0.3679 Player2 Wins: 0.39189 Dealer: 1.01414
# 20 Player Wins: 0.29657 Player2 Wins: 0.32549 Dealer: 1.22538
# 21 Player Wins: 0.16188 Player2 Wins: 0.19849 Dealer: 1.57123

# %%
#BLACKJACK FULL GAME THAT HAS DECK SHUFFLE WHEN CARDS RUN OUT
#CARD COUNTING

import numpy as N
import matplotlib.pyplot as plt
import random

#creates new deck
def makeDeck():
  d = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
         '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
         '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
         'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
         'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
         '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
  d = d * 60
  return d

def checkDeck(d):
  if len(d) == 0:
    return makeDeck()
  return d

#If card is 2 through 6, cardCount increases 1
#If card is 7 through 9, cardCount stays the same
#If card is 10 or 11, cardCount decreases by 1
def cardCounter(n):
  if (n >= 2 and n <= 6):
    return 1
  elif (n == 10 or n == 11):
    return -1
  else:
    return 0
  
def resetRunningCount(origDeck, deckindex, runningCount):
  if (origDeck != deckindex):
      return 0
  else:
    return runningCount

def determineTrueCount(deckindex, runningCount):
  length = len(deckindex)
  if (length > 234):
    if (runningCount/5.0 - 1 < 0): 
      return 1
    else:
      return runningCount/5.0 - 1
  elif (length <= 234 and length > 208):
    if (runningCount/4.5 - 1 < 0): 
      return 1
    else:
      return runningCount/4.5 - 1
  elif (length <= 208 and length > 182):
    if (runningCount/4.0 - 1 < 0): 
      return 1
    else:
      return runningCount/4.0 - 1
  elif (length <= 182 and length > 156):
    if (runningCount/3.5 - 1 < 0): 
      return 1
    else:
      return runningCount/3.5 - 1
  elif (length <= 156 and length > 130):
    if (runningCount/3.0 - 1 < 0): 
      return 1
    else:
      return runningCount/3.0 - 1
  elif (length <= 130 and length > 104):
    if (runningCount/2.5 - 1 < 0): 
      return 1
    else:
      return runningCount/2.5 - 1
  elif (length <= 104 and length > 78):
    if (runningCount/2.0 - 1 < 0): 
      return 1
    else:
      return runningCount/2.0 - 1
  elif (length <= 78 and length > 52):
    if (runningCount/1.5 - 1 < 0): 
      return 1
    else:
      return runningCount/1.5 - 1
  elif (length <= 52 and length > 26):
    if (runningCount/1.0 - 1 < 0): 
      return 1
    else:
      return runningCount/1.0 - 1
  else:
    if (runningCount/0.5 - 1 < 0): 
      return 1
    else:
      return runningCount/0.5 - 1
    
#n is the number which the player holds at
def game(n, loops):
  tie = 0 #Tie
  playerWin = 0 #Player wins
  houseWin = 0 #House wins
  moneyPlayer = 1000 #Player beginning money
  playerValueArray = []
  houseValueArray= []
  #creates deck
  deck = {'Ace of Hearts':11, '2 of Hearts':2, '3 of Hearts':3,'4 of Hearts':4, '5 of Hearts':5, '6 of Hearts':6, '7 of Hearts':7, 
         '8 of Hearts':8, '9 of Hearts':9, '10 of Hearts':10,'Jack of Hearts':10, 'Queen of Hearts':10, 'King of Hearts':10, 'Ace of Diamonds':11, 
         '2 of Diamonds':2, '3 of Diamonds':3,'4 of Diamonds':4,'5 of Diamonds':5, '6 of Diamonds':6, '7 of Diamonds':7, '8 of Diamonds':8, '9 of Diamonds':9, '10 of Diamonds':10, 
         'Jack of Diamonds':10, 'Queen of Diamonds':10, 'King of Diamonds':10,'Ace of Spades':11, '2 of Spades':2, '3 of Spades':3,'4 of Spades':4, '5 of Spades':5, '6 of Spades':6, '7 of Spades':7, '8 of Spades':8, '9 of Spades':9, '10 of Spades':10, 
         'Jack of Spades':10, 'Queen of Spades':10, 'King of Spades':10,'Ace of Clubs':11, '2 of Clubs':2, '3 of Clubs':3,'4 of Clubs':4, 
         '5 of Clubs':5, '6 of Clubs':6, '7 of Clubs':7, '8 of Clubs':8, '9 of Clubs':9, '10 of Clubs':10, 'Jack of Clubs':10, 'Queen of Clubs':10, 'King of Clubs':10}
  
  #list to call cards (LISTS ARE DIFFERENT FROM ARRAYS)
  deckindex = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
              '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
              '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
              'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
              'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
              '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
  deckindex = deckindex * 6
  runningCount = 0  
  for i in range(loops):
    countPlayerAce = 0
    countHouseAce = 0
    houseValue = 0 #House sum
    playerValue = 0 #Player sum
    bettingUnit = 10
    trueCount = determineTrueCount(deckindex, runningCount)
    #players make bets
    moneyPlayer -= bettingUnit * trueCount
    
    #gives house and player their both initial two cards
    origDeck = deckindex
    deckindex = checkDeck(deckindex)
    runningCount = resetRunningCount(origDeck, deckindex, runningCount)
    
    card = deckindex.pop(random.randint(0,len(deckindex)-1))
    playerValue += deck[card]
    if deck[card] == 11:
      countPlayerAce += 1
    runningCount += cardCounter(deck[card])
    origDeck = deckindex
    deckindex = checkDeck(deckindex)
    runningCount = resetRunningCount(origDeck, deckindex, runningCount)
    
    houseCard = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
    houseValue += houseCard
    if houseCard == 11:
      countHouseAce += 1
    runningCount += cardCounter(houseCard)
    origDeck = deckindex
    deckindex = checkDeck(deckindex)
    runningCount = resetRunningCount(origDeck, deckindex, runningCount)
    
    card = deckindex.pop(random.randint(0,len(deckindex)-1))
    playerValue += deck[card]
    if deck[card] == 11:
      countPlayerAce += 1
    runningCount += cardCounter(deck[card])
    origDeck = deckindex
    deckindex = checkDeck(deckindex)
    runningCount = resetRunningCount(origDeck, deckindex, runningCount)
    
    houseCard = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
    houseValue += houseCard
    if houseCard == 11:
      countHouseAce += 1
    runningCount += cardCounter(houseCard)

    #if you get 21 you win x1.5 your bet
    if playerValue == 21:
      playerWin += 1
      moneyPlayer += 2.5 * bettingUnit * trueCount
    else:
      #both player and house take their turns hitting
      while (playerValue < n):
        origDeck = deckindex
        deckindex = checkDeck(deckindex)
        runningCount = resetRunningCount(origDeck, deckindex, runningCount)
        add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
        runningCount += cardCounter(add)
        if add == 11:
          countPlayerAce += 1
        playerValue += add
        if playerValue > 21 and countPlayerAce > 0:
          playerValue -= 10
          countPlayerAce -= 1
      else:
        while (houseValue < 17):
          origDeck = deckindex
          deckindex = checkDeck(deckindex)
          runningCount = resetRunningCount(origDeck, deckindex, runningCount)
          add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
          runningCount += cardCounter(add)
          if add == 11:
            countHouseAce += 1
          houseValue += add
          if houseValue > 21 and countHouseAce > 0:
            houseValue -= 10
            countHouseAce -= 1
            
        #checks whether there are ties or who wins
        if playerValue > 21:
          houseWin += 1
        elif houseValue > 21:
          playerWin += 1
          moneyPlayer += 2 * bettingUnit * trueCount
        elif playerValue == houseValue:
          tie += 1
        else:
          if playerValue > houseValue:
            playerWin += 1
            moneyPlayer += 2 * bettingUnit * trueCount
          else:
            houseWin += 1
    playerValueArray.append(playerValue)
    houseValueArray.append(houseValue)
  print(1.0 * (moneyPlayer - 1000) / loops)
  print(str(n) + " Player Wins: " + str(1.0 * playerWin / loops))
  print(str(n) + " Player Wins: " + str(1.0 * tie / loops))
  return 1.0 * (moneyPlayer - 1000) / loops
  
#plot
wins = [game(i+1, 100000) for i in range(21)]
xAxis = [i+1 for i in range(21)]
plt.figure()
plt.xticks(N.arange(1,22,1))
plt.title("Average Amount of Money Won Per Game Using Card Counting")
plt.xlabel("Number Player Stands At")
plt.ylabel("Average amount of money won per game")
plt.plot(xAxis,wins)
plt.show()
# Out:
# -3.39623492063
# 1 Player Wins: 0.38823
# 1 Player Wins: 0.04626
# -3.57281396825
# 2 Player Wins: 0.3895
# 2 Player Wins: 0.04495
# -3.22798301587
# 3 Player Wins: 0.39
# 3 Player Wins: 0.04618
# -3.21761269841
# 4 Player Wins: 0.38689
# 4 Player Wins: 0.04718
# -3.37125361111
# 5 Player Wins: 0.3883
# 5 Player Wins: 0.04512
# -3.26466349206
# 6 Player Wins: 0.38838
# 6 Player Wins: 0.04608
# -2.96499742063
# 7 Player Wins: 0.38995
# 7 Player Wins: 0.04615
# -3.34333599206
# 8 Player Wins: 0.38944
# 8 Player Wins: 0.04725
# -2.9914372619
# 9 Player Wins: 0.39064
# 9 Player Wins: 0.05084
# -2.85439964286
# 10 Player Wins: 0.39788
# 10 Player Wins: 0.05253
# -2.78034218254
# 11 Player Wins: 0.40381
# 11 Player Wins: 0.05738
# -2.23428400794
# 12 Player Wins: 0.42111
# 12 Player Wins: 0.06222
# -2.1926606746
# 13 Player Wins: 0.42386
# 13 Player Wins: 0.0684
# -2.35500996032
# 14 Player Wins: 0.4214
# 14 Player Wins: 0.07523
# -2.21001428571
# 15 Player Wins: 0.42393
# 15 Player Wins: 0.08073
# -2.32850940476
# 16 Player Wins: 0.41961
# 16 Player Wins: 0.08975
# -2.6624434127
# 17 Player Wins: 0.41217
# 17 Player Wins: 0.0983
# -2.8572768254
# 18 Player Wins: 0.40381
# 18 Player Wins: 0.08536
# -4.23663075397
# 19 Player Wins: 0.36503
# 19 Player Wins: 0.06932
# -6.6698052381
# 20 Player Wins: 0.29564
# 20 Player Wins: 0.0528
# -11.5207063492
# 21 Player Wins: 0.16094
# 21 Player Wins: 0.01577

# %%
#BLACKJACK FULL GAME WITH BETS
import numpy as N
import matplotlib.pyplot as plt
import random

#creates new deck
def makeDeck():
  d = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
         '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
         '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
         'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
         'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
         '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
  d = d * 6
  return d

#n is the number which the player holds at
def game(n, loops):
  tie = 0 #Tie
  playerWin = 0 #Player wins
  houseWin = 0 #House wins
  moneyPlayer = 1000 #Player money starts out with
  playerValueArray = []
  houseValueArray= []
  
  #creates deck
  deck = {'Ace of Hearts':11, '2 of Hearts':2, '3 of Hearts':3,'4 of Hearts':4, '5 of Hearts':5, '6 of Hearts':6, '7 of Hearts':7, 
         '8 of Hearts':8, '9 of Hearts':9, '10 of Hearts':10,'Jack of Hearts':10, 'Queen of Hearts':10, 'King of Hearts':10, 'Ace of Diamonds':11, 
         '2 of Diamonds':2, '3 of Diamonds':3,'4 of Diamonds':4,'5 of Diamonds':5, '6 of Diamonds':6, '7 of Diamonds':7, '8 of Diamonds':8, '9 of Diamonds':9, '10 of Diamonds':10, 
         'Jack of Diamonds':10, 'Queen of Diamonds':10, 'King of Diamonds':10,'Ace of Spades':11, '2 of Spades':2, '3 of Spades':3,'4 of Spades':4, '5 of Spades':5, '6 of Spades':6, '7 of Spades':7, '8 of Spades':8, '9 of Spades':9, '10 of Spades':10, 
         'Jack of Spades':10, 'Queen of Spades':10, 'King of Spades':10,'Ace of Clubs':11, '2 of Clubs':2, '3 of Clubs':3,'4 of Clubs':4, 
         '5 of Clubs':5, '6 of Clubs':6, '7 of Clubs':7, '8 of Clubs':8, '9 of Clubs':9, '10 of Clubs':10, 'Jack of Clubs':10, 'Queen of Clubs':10, 'King of Clubs':10}
  
  #list to call cards (LISTS ARE DIFFERENT FROM ARRAYS)
  deckindex = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
              '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
              '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
              'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
              'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
              '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
  deckindex = deckindex * 6
  
  for i in range(loops):
    playerAce = 0
    houseAce = 0
    houseValue = 0 #House sum
    playerValue = 0 #Player sum
    bettingUnit = 10 #The betting unit
    #players make bets
    moneyPlayer -= bettingUnit
    #gives house and player their both initial two cards
    if len(deckindex) == 0:
      deckindex = makeDeck()
    playerValue += deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
    if len(deckindex) == 0:
      deckindex = makeDeck()
    houseValue += deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
    if len(deckindex) == 0:
      deckindex = makeDeck()
    playerValue += deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
    if len(deckindex) == 0:
      deckindex = makeDeck()
    houseValue += deck[deckindex.pop(random.randint(0,len(deckindex)-1))]

    #if you get 21 you win x1.5 your bet
    if playerValue == 21:
      playerWin += 1
      moneyPlayer += 2.5 * bettingUnit
    else:
      #both player and house take their turns hitting
      while (playerValue < n):
        if len(deckindex) == 0:
          deckindex = makeDeck()
        add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
        if add == 11:
          playerAce += 1
        playerValue += add
        if playerValue > 21 and playerAce > 0:
          playerValue -= 10
          playerAce -= 1 
      if houseValue == 21:
        houseWin += 1
      else:
        while (houseValue < 17):
          if len(deckindex) == 0:
            deckindex = makeDeck()
          add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
          if add == 11:
            houseAce += 1
          houseValue += add
          if houseValue > 21 and houseAce > 0:
            houseValue -= 10
            houseAce -= 1
        #checks whether there are ties or who wins
        if playerValue > 21:
          houseWin += 1
        elif houseValue > 21:
          playerWin +=1
          moneyPlayer += 2 * bettingUnit
        elif playerValue == houseValue:
          tie += 1
        else:
          if playerValue > houseValue :
            playerWin += 1
            moneyPlayer += 2 * bettingUnit
          else:
            houseWin += 1
            
    playerValueArray.append(playerValue)
    houseValueArray.append(houseValue)
  print(1.0 * (moneyPlayer - 1000) / loops)
  print(str(n) + " Player Wins: " + str(1.0 * playerWin / loops))
  return 1.0 * (moneyPlayer - 1000) / loops

wins = [game(i+1, 10) for i in range(21)]
xAxis = [i+1 for i in range(21)]
plt.figure()
plt.xticks(N.arange(1,22,1))
plt.title("Average Amount of Money Won Per Game Without Using Card Counting")
plt.xlabel("Number Player Stands At")
plt.ylabel("Average amount of money won per game")
plt.plot(xAxis,wins)
plt.show()
# Out:
# 0.0
# 1 Player Wins: 0.5
# 0.0
# 2 Player Wins: 0.5
# -1.5
# 3 Player Wins: 0.4
# -3.5
# 4 Player Wins: 0.3
# -1.5
# 5 Player Wins: 0.4
# -6.0
# 6 Player Wins: 0.2
# -5.5
# 7 Player Wins: 0.2
# 4.0
# 8 Player Wins: 0.7
# -4.0
# 9 Player Wins: 0.3
# -3.5
# 10 Player Wins: 0.3
# 0.0
# 11 Player Wins: 0.5
# 4.0
# 12 Player Wins: 0.7
# -8.0
# 13 Player Wins: 0.1
# 0.5
# 14 Player Wins: 0.5
# -2.0
# 15 Player Wins: 0.4
# 0.5
# 16 Player Wins: 0.5
# 0.0
# 17 Player Wins: 0.5
# -2.0
# 18 Player Wins: 0.4
# 2.5
# 19 Player Wins: 0.6
# 2.5
# 20 Player Wins: 0.6
# -8.0
# 21 Player Wins: 0.1

# %%
#With Counting Cards
def gameOne():
  import numpy as N
  import matplotlib.pyplot as plt
  import random

  #creates new deck
  def makeDeck():
    d = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
           '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
           '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
           'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
           'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
           '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
    d = d * 6
    return d

  def checkDeck(d):
    if len(d) == 0:
      return makeDeck()
    return d

  #If card is 2 through 6, cardCount increases 1
  #If card is 7 through 9, cardCount stays the same
  #If card is 10 or 11, cardCount decreases by 1
  def cardCounter(n):
    if (n >= 2 and n <= 6):
      return 1
    elif (n == 10 or n == 11):
      return -1
    else:
      return 0

  def resetRunningCount(origDeck, deckindex, runningCount):
    if (origDeck != deckindex):
        return 0 
    else:
      return runningCount

  def determineTrueCount(deckindex, runningCount):
    length = len(deckindex)
    if (length > 234):
      if (runningCount/5.0 - 1 < 0): 
        return 1
      else:
        return runningCount/5.0 - 1
    elif (length <= 234 and length > 208):
      if (runningCount/4.5 - 1 < 0): 
        return 1
      else:
        return runningCount/4.5 - 1
    elif (length <= 208 and length > 182):
      if (runningCount/4.0 - 1 < 0): 
        return 1
      else:
        return runningCount/4.0 - 1
    elif (length <= 182 and length > 156):
      if (runningCount/3.5 - 1 < 0): 
        return 1
      else:
        return runningCount/3.5 - 1
    elif (length <= 156 and length > 130):
      if (runningCount/3.0 - 1 < 0): 
        return 1
      else:
        return runningCount/3.0 - 1
    elif (length <= 130 and length > 104):
      if (runningCount/2.5 - 1 < 0): 
        return 1
      else:
        return runningCount/2.5 - 1
    elif (length <= 104 and length > 78):
      if (runningCount/2.0 - 1 < 0): 
        return 1
      else:
        return runningCount/2.0 - 1
    elif (length <= 78 and length > 52):
      if (runningCount/1.5 - 1 < 0): 
        return 1
      else:
        return runningCount/1.5 - 1
    elif (length <= 52 and length > 26):
      if (runningCount/1.0 - 1 < 0): 
        return 1
      else:
        return runningCount/1.0 - 1
    else:
      if (runningCount/0.5 - 1 < 0): 
        return 1
      else:
        return runningCount/0.5 - 1

  #n is the number which the player holds at
  def game(n, loops):
    tie = 0 #Tie
    playerWin = 0 #Player wins
    houseWin = 0 #House wins
    moneyPlayer = 1000 #Player beginning money
    playerValueArray = []
    houseValueArray= []
    #creates deck
    deck = {'Ace of Hearts':11, '2 of Hearts':2, '3 of Hearts':3,'4 of Hearts':4, '5 of Hearts':5, '6 of Hearts':6, '7 of Hearts':7, 
           '8 of Hearts':8, '9 of Hearts':9, '10 of Hearts':10,'Jack of Hearts':10, 'Queen of Hearts':10, 'King of Hearts':10, 'Ace of Diamonds':11, 
           '2 of Diamonds':2, '3 of Diamonds':3,'4 of Diamonds':4,'5 of Diamonds':5, '6 of Diamonds':6, '7 of Diamonds':7, '8 of Diamonds':8, '9 of Diamonds':9, '10 of Diamonds':10, 
           'Jack of Diamonds':10, 'Queen of Diamonds':10, 'King of Diamonds':10,'Ace of Spades':11, '2 of Spades':2, '3 of Spades':3,'4 of Spades':4, '5 of Spades':5, '6 of Spades':6, '7 of Spades':7, '8 of Spades':8, '9 of Spades':9, '10 of Spades':10, 
           'Jack of Spades':10, 'Queen of Spades':10, 'King of Spades':10,'Ace of Clubs':11, '2 of Clubs':2, '3 of Clubs':3,'4 of Clubs':4, 
           '5 of Clubs':5, '6 of Clubs':6, '7 of Clubs':7, '8 of Clubs':8, '9 of Clubs':9, '10 of Clubs':10, 'Jack of Clubs':10, 'Queen of Clubs':10, 'King of Clubs':10}

    #list to call cards (LISTS ARE DIFFERENT FROM ARRAYS)
    deckindex = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
                '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
                '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
                'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
                'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
                '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
    deckindex = deckindex * 6
    runningCount = 0
    for i in range(loops):
      playerAce = 0
      houseAce = 0
      houseValue = 0 #House sum
      playerValue = 0 #Player sum
      bettingUnit = 10 #The betting unit
      trueCount = determineTrueCount(deckindex, runningCount) #number of betting units 
      #players make bets
      moneyPlayer -= bettingUnit * trueCount

      #gives house and player their both initial two cards
      origDeck = deckindex
      deckindex = checkDeck(deckindex)
      runningCount = resetRunningCount(origDeck, deckindex, runningCount)
      x = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
      playerValue += x
      runningCount += cardCounter(x)
      origDeck = deckindex
      deckindex = checkDeck(deckindex)
      runningCount = resetRunningCount(origDeck, deckindex, runningCount)

      x = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
      houseValue += x
      runningCount += cardCounter(x)
      origDeck = deckindex
      deckindex = checkDeck(deckindex)
      runningCount = resetRunningCount(origDeck, deckindex, runningCount)

      x = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
      playerValue += x
      runningCount += cardCounter(x)
      origDeck = deckindex
      deckindex = checkDeck(deckindex)
      runningCount = resetRunningCount(origDeck, deckindex, runningCount)

      x = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
      houseValue += x
      runningCount += cardCounter(x)

      #if you get 21 you win x1.5 your bet
      if playerValue == 21:
        playerWin += 1
        moneyPlayer += 2.5 * bettingUnit * trueCount
      else:
        #both player and house take their turns hitting
        while (playerValue < n):
          origDeck = deckindex
          deckindex = checkDeck(deckindex)
          runningCount = resetRunningCount(origDeck, deckindex, runningCount)
          add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
          runningCount += cardCounter(add)
          if add == 11:
            playerAce += 1
          playerValue += add
          if playerValue > 21 and playerAce > 0:
            playerValue -= 10
            playerAce -= 1
        if houseValue == 21:
          houseWin += 1
        else:
          while (houseValue < 17):
            origDeck = deckindex
            deckindex = checkDeck(deckindex)
            runningCount = resetRunningCount(origDeck, deckindex, runningCount)
            add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
            runningCount += cardCounter(add)
            if add == 11:
              houseAce += 1
            houseValue += add
            if houseValue > 21 and houseAce > 0:
              houseValue -= 10
              houseAce -= 1
          #checks whether there are ties or who wins
          if playerValue > 21:
            houseWin += 1
          elif houseValue > 21:
            playerWin += 1
            moneyPlayer += 2 * bettingUnit * trueCount
          elif playerValue == houseValue:
            tie += 1
          else:
            if playerValue > houseValue:
              playerWin += 1
              moneyPlayer += 2 * bettingUnit * trueCount
            else:
              houseWin += 1
      playerValueArray.append(playerValue)
      houseValueArray.append(houseValue)
    print(1.0 * (moneyPlayer - 1000) / loops)
    #print(str(n) + " Player Wins: " + str(1.0 * playerWin / loops))
    return 1.0 * (moneyPlayer - 1000) / loops

  #plot
  wins = [game(i+11, 100000) for i in range(6)]
  xAxis = [i+11 for i in range(6)]
  plt.figure()
  plt.xticks(N.arange(11,17,1))
  plt.plot(xAxis,wins)
  
#Without Counting Cards
def gameTwo():
  
  import numpy as N
  import matplotlib.pyplot as plt
  import random
  #creates new deck
  def makeDeck():
    d = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
           '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
           '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
           'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
           'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
           '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
    d = d * 6
    return d

  #n is the number which the player holds at
  def game(n, loops):
    tie = 0 #Tie
    playerWin = 0 #Player wins
    houseWin = 0 #House wins
    cardCount = 2 #Card count for the player
    moneyPlayer = 1000 #Player money starts out with
    playerValueArray = []
    houseValueArray= []

    #creates deck
    deck = {'Ace of Hearts':11, '2 of Hearts':2, '3 of Hearts':3,'4 of Hearts':4, '5 of Hearts':5, '6 of Hearts':6, '7 of Hearts':7, 
           '8 of Hearts':8, '9 of Hearts':9, '10 of Hearts':10,'Jack of Hearts':10, 'Queen of Hearts':10, 'King of Hearts':10, 'Ace of Diamonds':11, 
           '2 of Diamonds':2, '3 of Diamonds':3,'4 of Diamonds':4,'5 of Diamonds':5, '6 of Diamonds':6, '7 of Diamonds':7, '8 of Diamonds':8, '9 of Diamonds':9, '10 of Diamonds':10, 
           'Jack of Diamonds':10, 'Queen of Diamonds':10, 'King of Diamonds':10,'Ace of Spades':11, '2 of Spades':2, '3 of Spades':3,'4 of Spades':4, '5 of Spades':5, '6 of Spades':6, '7 of Spades':7, '8 of Spades':8, '9 of Spades':9, '10 of Spades':10, 
           'Jack of Spades':10, 'Queen of Spades':10, 'King of Spades':10,'Ace of Clubs':11, '2 of Clubs':2, '3 of Clubs':3,'4 of Clubs':4, 
           '5 of Clubs':5, '6 of Clubs':6, '7 of Clubs':7, '8 of Clubs':8, '9 of Clubs':9, '10 of Clubs':10, 'Jack of Clubs':10, 'Queen of Clubs':10, 'King of Clubs':10}

    #list to call cards (LISTS ARE DIFFERENT FROM ARRAYS)
    deckindex = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
                '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
                '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
                'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
                'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
                '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
    deckindex = deckindex * 6

    for i in range(loops):
      playerAce = 0
      houseAce = 0
      houseValue = 0 #House sum
      playerValue = 0 #Player sum
      bettingUnit = 10 #The betting unit

      #players make bets
      moneyPlayer -= bettingUnit
      #gives house and player their both initial two cards
      if len(deckindex) == 0:
        deckindex = makeDeck()
      card = deckindex.pop(random.randint(0,len(deckindex)-1))
      playerValue += deck[card]
      if deck[card] == 11:
        playerAce += 1
       
      if len(deckindex) == 0:
        deckindex = makeDeck()
      houseCard = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
      houseValue += houseCard
      if houseCard == 11:
        houseAce += 1

      if len(deckindex) == 0:
        deckindex = makeDeck()
      card = deckindex.pop(random.randint(0,len(deckindex)-1))
      playerValue += deck[card]
      if deck[card] == 11:
        playerAce += 1
        
      if len(deckindex) == 0:
        deckindex = makeDeck()
      houseCard = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
      houseValue += houseCard
      if houseCard == 11:
        houseAce += 1

      #if you get 21 you win x1.5 your bet
      if playerValue == 21:
        playerWin += 1
        moneyPlayer += 2.5 * bettingUnit
      else:
        #both player and house take their turns hitting
        while (playerValue < n):
          if len(deckindex) == 0:
            deckindex = makeDeck()
          add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
          if add == 11:
            playerAce += 1
          playerValue += add
          cardCount += 1
          if cardCount == 5:
            break #If player has 5 cards without busting, they win
          if playerValue > 21 and playerAce > 0:
            playerValue -= 10
            playerAce -= 1
        if houseValue == 21:
          houseWin += 1
        else:
          while (houseValue < 17):
            if len(deckindex) == 0:
              deckindex = makeDeck()
            add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
            if add == 11:
              houseAce += 1
            houseValue += add
            if houseValue > 21 and houseAce > 0:
              houseValue -= 10
              houseAce -= 1
          if cardCount == 5:
            houseWin += 1 #If player has 5 cards without busting, they win
          #checks whether there are ties or who wins
          if playerValue > 21:
            houseWin += 1
          elif houseValue > 21:
            playerWin += 1
            moneyPlayer += 2 * bettingUnit
          elif playerValue == houseValue:
            tie += 1
          else:
            if playerValue > houseValue:
              playerWin += 1
              moneyPlayer += 2 * bettingUnit
            else:
              houseWin += 1
      playerValueArray.append(playerValue)
      houseValueArray.append(houseValue)
    print(1.0 * (moneyPlayer - 1000) / loops)
    #print(str(n) + " Player Wins: " + str(1.0 * playerWin / loops))
    return 1.0 * (moneyPlayer - 1000) / loops

  wins = [game(i+11, 100000) for i in range(6)]
  xAxis = [i+11 for i in range(6)]
  plt.xticks(N.arange(11,17,1))
  plt.title("Player Money Increase Based on Strategy")
  plt.xlabel("Number Player Stands At")
  plt.ylabel("Average Dollars Won Per Game")
  plt.plot(xAxis,wins)
  plt.legend(["With Counting Cards","Without Counting Cards"])
  plt.show()
gameOne()
gameTwo()
# Out:
# -1.69278376984
# -1.36917349206
# -1.42314305556
# -1.35971
# -1.45379373016
# -1.79961583333
# -1.62865
# -1.38445
# -1.27765
# -1.2765
# -1.30675
# -1.3053

# %%
#GRAPH THAT SHOWS WIN RATE
#BLACKJACK FULL GAME THAT HAS DECK SHUFFLE WHEN CARDS RUN OUT
import numpy as N
import matplotlib.pyplot as plt
import random

#creates new deck
def makeDeck():
  d = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
         '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
         '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
         'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
         'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
         '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
  return d

#n is the number which the player holds at
def game(n, loops):
  tie = 0 #Tie
  playerWin = 0 #Player wins
  houseWin = 0 #House wins
  playerValueArray = []
  houseValueArray= []
  
  #creates deck
  deck = {'Ace of Hearts':11, '2 of Hearts':2, '3 of Hearts':3,'4 of Hearts':4, '5 of Hearts':5, '6 of Hearts':6, '7 of Hearts':7, 
         '8 of Hearts':8, '9 of Hearts':9, '10 of Hearts':10,'Jack of Hearts':10, 'Queen of Hearts':10, 'King of Hearts':10, 'Ace of Diamonds':11, 
         '2 of Diamonds':2, '3 of Diamonds':3,'4 of Diamonds':4,'5 of Diamonds':5, '6 of Diamonds':6, '7 of Diamonds':7, '8 of Diamonds':8, '9 of Diamonds':9, '10 of Diamonds':10, 
         'Jack of Diamonds':10, 'Queen of Diamonds':10, 'King of Diamonds':10,'Ace of Spades':11, '2 of Spades':2, '3 of Spades':3,'4 of Spades':4, '5 of Spades':5, '6 of Spades':6, '7 of Spades':7, '8 of Spades':8, '9 of Spades':9, '10 of Spades':10, 
         'Jack of Spades':10, 'Queen of Spades':10, 'King of Spades':10,'Ace of Clubs':11, '2 of Clubs':2, '3 of Clubs':3,'4 of Clubs':4, 
         '5 of Clubs':5, '6 of Clubs':6, '7 of Clubs':7, '8 of Clubs':8, '9 of Clubs':9, '10 of Clubs':10, 'Jack of Clubs':10, 'Queen of Clubs':10, 'King of Clubs':10}
  
  #list to call cards (LISTS ARE DIFFERENT FROM ARRAYS)
  deckindex = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
              '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
              '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
              'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
              'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
              '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
    #deckindex = deckindex * x
  for i in range(loops):
    playerAce = 0
    houseAce = 0
    houseValue = 0 #House sum
    playerValue = 0 #Player sum

    #gives house and player their both initial two cards
    if len(deckindex) == 0:
      deckindex = makeDeck()
    card = deckindex.pop(random.randint(0,len(deckindex)-1))
    playerValue += deck[card]
    if deck[card] == 11:
      playerAce += 1

    if len(deckindex) == 0:
      deckindex = makeDeck()
    houseCard = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
    houseValue += houseCard
    if houseCard == 11:
      houseAce += 1

    if len(deckindex) == 0:
      deckindex = makeDeck()
    card = deckindex.pop(random.randint(0,len(deckindex)-1))
    playerValue += deck[card]
    if deck[card] == 11:
      playerAce += 1

    if len(deckindex) == 0:
      deckindex = makeDeck()
    houseCard = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
    houseValue += houseCard
    if houseCard == 11:
      houseAce += 1

    #if you get 21 you win
    if playerValue == 21:
      playerWin += 1
    else:
      #both player and house take their turns hitting
      while (playerValue < 14):
        if len(deckindex) == 0:
          deckindex = makeDeck()
        add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
        if add == 11:
          playerAce += 1
        playerValue += add
        if playerValue > 21 and playerAce > 0:
          playerValue -= 10
          playerAce -= 1
      if houseValue == 21:
        houseWin += 1
      else:
        while (houseValue < 17):
          if len(deckindex) == 0:
            deckindex = makeDeck()
          add = deck[deckindex.pop(random.randint(0,len(deckindex)-1))]
          if add == 11:
            houseAce += 1
          houseValue += add
          if houseValue > 21 and houseAce > 0:
            houseValue -= 10
            houseAce -= 1
        #checks whether there are ties or who wins
        if playerValue > 21:
          houseWin += 1
        elif houseValue > 21:
          playerWin +=1
        elif playerValue == houseValue:
          tie += 1
        else:
          if playerValue > houseValue:
            playerWin += 1
          else:
            houseWin += 1
    playerValueArray.append(playerValue)
    houseValueArray.append(houseValue)

  #print(str(n) + " Player Wins: " + str(1.0 * playerWin / loops))
  return 1.0 * playerWin / loops
"""
#plot
wins = [game(i+1, 100000) for i in range(21)]
xAxis = [i+1 for i in range(21)]
plt.figure()
plt.xticks(N.arange(1,22,1))
plt.title("Player Win Percentage based on Strategy")
plt.xlabel("Number Player Stands At")
plt.ylabel("Percentage of Wins")
plt.plot(xAxis,wins)
plt.show()
"""

wins = [game(14, 10 * i + 1) for i in range(2000)]
xAxis = [10 * i + 1 for i in range(2000)]
plt.figure()
plt.xticks(N.arange(0,20001,5000))
plt.yticks(N.arange(0,1.01,0.1))
plt.title("Games simulated versus Percentage of Wins")
plt.xlabel("Games simulated")
plt.ylabel("Percentage of Wins")
plt.plot(xAxis,wins)
plt.show()

# %%
#BLACKJACK GAME HUMAN VS COMPUTER
#DO NOT TOUCH 
#NO ONE BETTER TOUCH THIS PIECE OF CODE
#DO NOT EVEN THINK ABOUT IT
import numpy as N
import matplotlib.pyplot as plt
import random

#creates new deck
def makeDeck():
  d = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
         '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
         '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
         'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
         'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
         '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
  return d

def game():
  cardList = []
  houseCardList = []
  #creates deck
  deck = {'Ace of Hearts':11, '2 of Hearts':2, '3 of Hearts':3,'4 of Hearts':4, '5 of Hearts':5, '6 of Hearts':6, '7 of Hearts':7, 
         '8 of Hearts':8, '9 of Hearts':9, '10 of Hearts':10,'Jack of Hearts':10, 'Queen of Hearts':10, 'King of Hearts':10, 'Ace of Diamonds':11, 
         '2 of Diamonds':2, '3 of Diamonds':3,'4 of Diamonds':4,'5 of Diamonds':5, '6 of Diamonds':6, '7 of Diamonds':7, '8 of Diamonds':8, '9 of Diamonds':9, '10 of Diamonds':10, 
         'Jack of Diamonds':10, 'Queen of Diamonds':10, 'King of Diamonds':10,'Ace of Spades':11, '2 of Spades':2, '3 of Spades':3,'4 of Spades':4, '5 of Spades':5, '6 of Spades':6, '7 of Spades':7, '8 of Spades':8, '9 of Spades':9, '10 of Spades':10, 
         'Jack of Spades':10, 'Queen of Spades':10, 'King of Spades':10,'Ace of Clubs':11, '2 of Clubs':2, '3 of Clubs':3,'4 of Clubs':4, 
         '5 of Clubs':5, '6 of Clubs':6, '7 of Clubs':7, '8 of Clubs':8, '9 of Clubs':9, '10 of Clubs':10, 'Jack of Clubs':10, 'Queen of Clubs':10, 'King of Clubs':10}
  
  #list to call cards (LISTS ARE DIFFERENT FROM ARRAYS)
  deckindex = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
              '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
              '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
              'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
              'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
              '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
  countHumanAce = 0
  countHouseAce = 0
  houseValue = 0 #House sum
  humanValue = 0 #Human sum

  #gives house and human both initial two cards
  if len(deckindex) == 0:
    deckindex = makeDeck()
  card = deckindex.pop(random.randint(0,len(deckindex)-1))
  cardList.append(card)
  humanValue += deck[card]
  if deck[card] == 11:
    countHumanAce += 1
  if len(deckindex) == 0:
    deckindex = makeDeck()
  houseCard = deckindex.pop(random.randint(0,len(deckindex)-1))
  houseCardList.append(houseCard)
  houseValue += deck[houseCard]
  print("The card that is face up for the house is " + card)
  if houseCard == 11:
    countHouseAce += 1
  if len(deckindex) == 0:
    deckindex = makeDeck()
  card = deckindex.pop(random.randint(0,len(deckindex)-1))
  cardList.append(card)
  humanValue += deck[card]
  if deck[card] == 11:
    countHumanAce += 1
  if len(deckindex) == 0:
    deckindex = makeDeck()
  houseCard = deckindex.pop(random.randint(0,len(deckindex)-1))
  houseCardList.append(houseCard)
  houseValue += deck[houseCard]
  if houseCard == 11:
    countHouseAce += 1
 
  #if you get 21, you win!
  print("Your first two cards are: " + cardList[0] + " and " + cardList[1])
  if humanValue == 21:
    print("The house's hand: " + str(houseCardList))
    return "You win"
  else:
    name = raw_input("Would you like to hit or stay? ")
  while (name != "hit" and name != "stay"):
    name = raw_input("Invalid input. Please try again. Would you like to hit or stay?")
  while (name == "hit"):
    if len(deckindex) == 0:
      deckindex = makeDeck()
    card = deckindex.pop(random.randint(0,len(deckindex)-1))
    cardList.append(card)
    humanValue += deck[card]
    if deck[card] == 11:
      countHumanAce += 1
    if humanValue == 21:
      print("Your hand: " + str(cardList))
      print("The house's hand: " + str(houseCardList))
      return "You win"
    if humanValue > 21:
      if humanValue > 21 and countHumanAce > 0:
        humanValue -= 10
        countHumanAce -= 1
      else:
        print("Your hand: " + str(cardList))
        print("The house's hand: " + str(houseCardList))
        return "You lose"
    name = raw_input(str(cardList) + "\n Would you like to hit or stay? ")
    while (name != "hit" and name != "stay"):
      name = raw_input("Invalid input. Please try again. Would you like to hit or stay?")

  while (houseValue < 17):
    if len(deckindex) == 0:
      deckindex = makeDeck()
    houseCard = deckindex.pop(random.randint(0,len(deckindex)-1))
    houseCardList.append(houseCard)
    houseValue += deck[houseCard]
    if deck[houseCard] == 11:
      countHouseAce += 1
    if houseValue > 21 and countHouseAce > 0:
      houseValue -= 10
      countHouseAce -= 1
  #checks whether there are ties or who wins
  if humanValue > 21:
    print("Your hand: " + str(cardList))
    print("The house's hand: " + str(houseCardList))
    return "You lose"
  elif houseValue > 21:
    print("Your hand: " + str(cardList))
    print("The house's hand: " + str(houseCardList))
    return "You win"
  elif humanValue == houseValue:
    print("Your hand: " + str(cardList))
    print("The house's hand: " + str(houseCardList))
    return "Push (Tie)"
  else:
    if humanValue > houseValue:
      print("Your hand: " + str(cardList))
      print("The house's hand: " + str(houseCardList))
      return "You win"
    else:
      print("Your hand: " + str(cardList))
      print("The house's hand: " + str(houseCardList))
      return "You lose"
game()
# Out:
# The card that is face up for the house is 5 of Hearts
# Your first two cards are: 5 of Hearts and 5 of Diamonds
# Would you like to hit or stay? hit
# ['5 of Hearts', '5 of Diamonds', 'King of Diamonds']
#  Would you like to hit or stay? stay
# Your hand: ['5 of Hearts', '5 of Diamonds', 'King of Diamonds']
# The house's hand: ['Queen of Clubs', '6 of Diamonds', '2 of Hearts']
# 'You win'

# %%
#BLACKJACK GAME HUMAN VS COMPUTER
import numpy as N
import matplotlib.pyplot as plt
import random

#creates new deck
def makeDeck():
  d = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
         '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
         '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
         'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
         'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
         '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
  return d

def game():
  cardList = []
  houseCardList = []
  #creates deck
  deck = {'Ace of Hearts':11, '2 of Hearts':2, '3 of Hearts':3,'4 of Hearts':4, '5 of Hearts':5, '6 of Hearts':6, '7 of Hearts':7, 
         '8 of Hearts':8, '9 of Hearts':9, '10 of Hearts':10,'Jack of Hearts':10, 'Queen of Hearts':10, 'King of Hearts':10, 'Ace of Diamonds':11, 
         '2 of Diamonds':2, '3 of Diamonds':3,'4 of Diamonds':4,'5 of Diamonds':5, '6 of Diamonds':6, '7 of Diamonds':7, '8 of Diamonds':8, '9 of Diamonds':9, '10 of Diamonds':10, 
         'Jack of Diamonds':10, 'Queen of Diamonds':10, 'King of Diamonds':10,'Ace of Spades':11, '2 of Spades':2, '3 of Spades':3,'4 of Spades':4, '5 of Spades':5, '6 of Spades':6, '7 of Spades':7, '8 of Spades':8, '9 of Spades':9, '10 of Spades':10, 
         'Jack of Spades':10, 'Queen of Spades':10, 'King of Spades':10,'Ace of Clubs':11, '2 of Clubs':2, '3 of Clubs':3,'4 of Clubs':4, 
         '5 of Clubs':5, '6 of Clubs':6, '7 of Clubs':7, '8 of Clubs':8, '9 of Clubs':9, '10 of Clubs':10, 'Jack of Clubs':10, 'Queen of Clubs':10, 'King of Clubs':10}
  
  #list to call cards (LISTS ARE DIFFERENT FROM ARRAYS)
  deckindex = ['Ace of Hearts', '2 of Hearts', '3 of Hearts','4 of Hearts', '5 of Hearts', '6 of Hearts', '7 of Hearts', 
              '8 of Hearts', '9 of Hearts', '10 of Hearts','Jack of Hearts', 'Queen of Hearts', 'King of Hearts', 'Ace of Diamonds', 
              '2 of Diamonds', '3 of Diamonds','4 of Diamonds','5 of Diamonds', '6 of Diamonds', '7 of Diamonds', '8 of Diamonds', '9 of Diamonds', '10 of Diamonds', 
              'Jack of Diamonds', 'Queen of Diamonds', 'King of Diamonds','Ace of Spades', '2 of Spades', '3 of Spades','4 of Spades', '5 of Spades', '6 of Spades', '7 of Spades', '8 of Spades', '9 of Spades', '10 of Spades', 
              'Jack of Spades', 'Queen of Spades', 'King of Spades', 'Ace of Clubs', '2 of Clubs', '3 of Clubs','4 of Clubs', 
              '5 of Clubs', '6 of Clubs', '7 of Clubs', '8 of Clubs', '9 of Clubs', '10 of Clubs', 'Jack of Clubs', 'Queen of Clubs', 'King of Clubs']
  countHumanAce = 0
  countHouseAce = 0
  houseValue = 0 #House sum
  humanValue = 0 #Human sum

  #gives house and human both initial two cards
  if len(deckindex) == 0:
    deckindex = makeDeck()
  card = deckindex.pop(random.randint(0,len(deckindex)-1))
  cardList.append(card)
  firstCard = deck[card]
  humanValue += deck[card]
  if deck[card] == 11:
    countHumanAce += 1
  if len(deckindex) == 0:
    deckindex = makeDeck()
  houseCard = deckindex.pop(random.randint(0,len(deckindex)-1))
  firstHouseCard = houseCard
  houseCardList.append(houseCard)
  houseValue += deck[houseCard]
  if houseCard == 11:
    countHouseAce += 1
  if len(deckindex) == 0:
    deckindex = makeDeck()
  card = deckindex.pop(random.randint(0,len(deckindex)-1))
  cardList.append(card)
  humanValue += deck[card]
  if deck[card] == 11:
    countHumanAce += 1
  if len(deckindex) == 0:
    deckindex = makeDeck()
  houseCard = deckindex.pop(random.randint(0,len(deckindex)-1))
  houseCardList.append(houseCard)
  houseValue += deck[houseCard]
  if houseCard == 11:
    countHouseAce += 1
 
  #if you get 21, you win!
  if humanValue == 21:
    print("The card that is face up for the house is " + firstHouseCard + "\n" + "Your first two cards are: " + cardList[0] + " and " + cardList[1] + "\n" + "The house's hand: " + str(houseCardList))
    return "You win"
  elif deck[card] == firstCard:
    name = raw_input("The card that is face up for the house is " + firstHouseCard + "\n" + "Your first two cards are: " + cardList[0] + " and " + cardList[1] + "\n" + "Would you like to split, hit, or stay? ")
    while (name != "hit" and name != "stay" and name != "split"):
      name = raw_input("Invalid input. Please try again. Would you like to split, hit or stay?")
  else:
    name = raw_input("The card that is face up for the house is " + firstHouseCard + "\n" + "Your first two cards are: " + cardList[0] + " and " + cardList[1] + "\n" + "Would you like to hit or stay? ")
    while (name != "hit" and name != "stay"):
      name = raw_input("Invalid input. Please try again. Would you like to hit or stay?")
  if name == "split":
    if firstCard == 11:
      countAce1 = 1
      countAce2 = 1
    else:
      countAce1 = 0
      countAce2 = 0
      
    #first split hand
    humanHand1 = firstCard
    cardList1 = [cardList[0]]
    if len(deckindex) == 0:
      deckindex = makeDeck()
    card = deckindex.pop(random.randint(0,len(deckindex)-1))
    cardList1.append(card)
    humanHand1 += deck[card]
    if deck[card] == 11:
      countHumanAce += 1
    if humanHand1 == 21:
      print("Your first hand: " + str(cardList))
      print("The house's hand: " + str(houseCardList))
      print("You won with your first hand")
      check = True
    else:
      check = False
    if check == False:
      name = raw_input("Your first hand is now: " + str(cardList1) + "\n"+ "Would you like to hit or stay? ")
      while (name != "hit" and name != "stay"):
        name = raw_input("Invalid input. Please try again. Would you like to hit or stay?")
      while (name == "hit"):
        if len(deckindex) == 0:
          deckindex = makeDeck()
        card = deckindex.pop(random.randint(0,len(deckindex)-1))
        cardList1.append(card)
        humanHand1 += deck[card]
        if deck[card] == 11:
          countAce1 += 1
        if humanHand1 == 21:
          check = True
          print("Your first hand: " + str(cardList1))
          print("The house's hand: " + str(houseCardList))
          print("You win with your first hand \n ")
        if humanHand1 > 21 and countAce1 > 0:
          check = True
          humanHand1 -= 10
          countAce1 -= 1
        if check == False:
          name = raw_input("Your first hand now: " + str(cardList1) + "\nWould you like to hit or stay? ")
          while (name != "hit" and name != "stay"):
            name = raw_input("Invalid input. Please try again. Would you like to hit or stay?")
    while (houseValue < 17):
      if len(deckindex) == 0:
        deckindex = makeDeck()
      houseCard = deckindex.pop(random.randint(0,len(deckindex)-1))
      houseCardList.append(houseCard)
      houseValue += deck[houseCard]
      if deck[houseCard] == 11:
        countHouseAce += 1
      if houseValue > 21 and countHouseAce > 0:
        houseValue -= 10
        countHouseAce -= 1
    if (humanHand1 > 21):
      print("Your first hand: " + str(cardList1))
      print("The house's hand: " + str(houseCardList))
      print("You lose with your first hand")
    elif houseValue > 21:
      print("Your first hand: " + str(cardList1))
      print("The house's hand: " + str(houseCardList))
      print("You win with your first hand")
    elif humanHand1 == houseValue:
      print("Your first hand: " + str(cardList1))
      print("The house's hand: " + str(houseCardList))
      print("Push (Tie) with your first hand")
    else:
      if humanHand1 > houseValue:
        print("Your first hand: " + str(cardList1))
        print("The house's hand: " + str(houseCardList))
        print("You win with your first hand")
      else:
        print("Your first hand: " + str(cardList1))
        print("The house's hand: " + str(houseCardList))
        print("You lose with your first hand")
      
    #2nd split hand  
    humanHand2 = firstCard
    cardList2 = [cardList[1]]
    if len(deckindex) == 0:
      deckindex = makeDeck()
    card = deckindex.pop(random.randint(0,len(deckindex)-1))
    cardList2.append(card)
    humanHand2 += deck[card]
    if humanHand2 == 21:
        print("Your second hand: " + str(cardList2))
        print("The house's hand: " + str(houseCardList))
        return("You won the second hand")
    if deck[card] == 11:
      countAce2 += 1
    name = raw_input("\nYour second hand is now: " + str(cardList2) + "\nWould you like to hit or stay? ")
    while (name != "hit" and name != "stay"):
      name = raw_input("Invalid input. Please try again. Would you like to hit or stay?")
    while (name == "hit"):
      if len(deckindex) == 0:
        deckindex = makeDeck()
      card = deckindex.pop(random.randint(0,len(deckindex)-1))
      cardList2.append(card)
      humanHand2 += deck[card]
      if deck[card] == 11:
        countAce2 += 1
      if humanHand2 == 21:
        print("Your second hand: " + str(cardList2))
        print("The house's hand: " + str(houseCardList))
        return "You win"
      if humanHand2 > 21:
        if countAce2 > 0:
          humanHand2 -= 10
          countAce2 -= 1
        else:
          print("Your second hand: " + str(cardList2))
          print("The house's hand: " + str(houseCardList))
          return "You lose"
      name = raw_input("Your second hand now: " + str(cardList2) + "\nWould you like to hit or stay? ")
      while (name != "hit" and name != "stay"):
        name = raw_input("Invalid input. Please try again. Would you like to hit or stay?")
    if (humanHand2 > 21):
      print("Your second hand: " + str(cardList2))
      print("The house's hand: " + str(houseCardList))
      return "You lose with your second hand"
    elif houseValue > 21:
      print("Your second hand: " + str(cardList2))
      print("The house's hand: " + str(houseCardList))
      return "You win with your second hand"
    elif humanHand2 == houseValue:
      print("Your second hand: " + str(cardList2))
      print("The house's hand: " + str(houseCardList))
      return "Push (Tie) with your second hand"
    else:
      if humanHand2 > houseValue:
        print("Your second hand: " + str(cardList2))
        print("The house's hand: " + str(houseCardList))
        return "You win with your second hand"
      else:
        print("Your second hand: " + str(cardList2))
        print("The house's hand: " + str(houseCardList))
        return "You lose with your second hand"
  #no split
  else:
    while (name == "hit"):
      if len(deckindex) == 0:
        deckindex = makeDeck()
      card = deckindex.pop(random.randint(0,len(deckindex)-1))
      cardList.append(card)
      humanValue += deck[card]
      if deck[card] == 11:
        countHumanAce += 1
      if humanValue == 21:
        print("Your hand: " + str(cardList))
        print("The house's hand: " + str(houseCardList))
        return "You win"
      if humanValue > 21:
        if countHumanAce > 0:
          humanValue -= 10
          countHumanAce -= 1
        else:
          print("Your hand: " + str(cardList))
          print("The house's hand: " + str(houseCardList))
          return "You lose"
      name = raw_input("Your first hand now: " + str(cardList) + "\nWould you like to hit or stay? ")
      while (name != "hit" and name != "stay"):
        name = raw_input("Invalid input. Please try again. Would you like to hit or stay?")
    while (houseValue < 17):
      if len(deckindex) == 0:
        deckindex = makeDeck()
      houseCard = deckindex.pop(random.randint(0,len(deckindex)-1))
      houseCardList.append(houseCard)
      houseValue += deck[houseCard]
      if deck[houseCard] == 11:
        countHouseAce += 1
      if houseValue > 21 and countHouseAce > 0:
          houseValue -= 10
          countHouseAce -= 1
  #checks whether there are ties or who wins
  if humanValue > 21:
    print("Your hand: " + str(cardList))
    print("The house's hand: " + str(houseCardList))
    return "You lose"
  elif houseValue > 21:
    print("Your hand: " + str(cardList))
    print("The house's hand: " + str(houseCardList))
    return "You win"
  elif humanValue == houseValue:
    print("Your hand: " + str(cardList))
    print("The house's hand: " + str(houseCardList))
    return "Push (Tie)"
  else:
    if humanValue > houseValue:
      print("Your hand: " + str(cardList))
      print("The house's hand: " + str(houseCardList))
      return "You win"
    else:
      print("Your hand: " + str(cardList))
      print("The house's hand: " + str(houseCardList))
      return "You lose"
game()
# Out:
# The card that is face up for the house is Jack of Clubs
# Your first two cards are: 2 of Hearts and 3 of Hearts
# Would you like to hit or stay? hit
# Your first hand now: ['2 of Hearts', '3 of Hearts', '8 of Hearts']
# Would you like to hit or stay? hit
# Your first hand now: ['2 of Hearts', '3 of Hearts', '8 of Hearts', '6 of Clubs']
# Would you like to hit or stay? stay
# Your hand: ['2 of Hearts', '3 of Hearts', '8 of Hearts', '6 of Clubs']
# The house's hand: ['Jack of Clubs', 'Queen of Hearts']
# 'You lose'
